# %% [markdown]
# ## 02 — Microstructure Features
# Build 5-min bars, daily RV, OFI, depth imbalance, LOB slope; assemble and save `micro_features_5m.parquet`. Uses `src.data.features` and clean MBP-10 parquet.
