# %% [markdown]
# ### Investigating the **RAW MBO Data** (includes all order book levels and all futures contracts at a given time)

# %%
import databento as db
import pandas as pd
from pathlib import Path
from IPython.display import display

# Constants 
CORN_MONTH_ORDER = ["H", "K", "N", "U", "Z"]  # March, May, July, Sep, Dec
ACTION_CODES = ["T", "A", "R", "C", "F", "N", "M"]
ACTION_LABELS = ["trades", "adds", "clears", "cancels", "fills", "none", "modify"]


def show_info_for_single_day_data(data_path: str) -> None:
    """
    Display a quick summary of a single day's corn futures market data.
    
    - sample rows and column types
    - action breakdown table (trades, adds, cancels, etc.)
    - symbol counts
    - front month contract identification
    
    """
    
    # Check if file exists
    file_path = Path(data_path)
    if not file_path.exists():
        print(f" file NOT found: {data_path}")
        print(f" > This day does not exist in the dataset. Check the filename.")
        return None
    
    # Load data
    corn_dbn_file = db.DBNStore.from_file(data_path)
    corn_book_df = corn_dbn_file.to_df()

    # Display sample and column types
    display(corn_book_df.head(20))
    print(corn_book_df.dtypes)
    
    # Action stats (one pass over the action column for efficiency)
    action_counts = corn_book_df["action"].value_counts()
    action_counts_dict = {code: int(action_counts.get(code, 0)) for code in ACTION_CODES}
    
    # Summary table
    summary_df = pd.DataFrame({
        "metric": ACTION_LABELS,
        "action_code": ACTION_CODES,
        "count": list(action_counts_dict.values()),
    })
    
    display(summary_df)
    
    # Symbol counts
    symbol_counts = corn_book_df["symbol"].value_counts()
    symbol_counts_df = pd.DataFrame({
        "symbol": symbol_counts.index,
        "count": symbol_counts.values,
    })
    display(symbol_counts_df)
    
    # Find front-month contract (earliest expiration among base contracts)
    base_contracts = symbol_counts_df[symbol_counts_df["symbol"].str.len() <= 4].copy()
    
    
    # Symbol format: ZC + month_letter + year_digit (e.g., ZCH6 = March 2026)
    base_contracts.loc[:, "month_letter"] = base_contracts["symbol"].str[2]
    base_contracts.loc[:, "year_digit"] = base_contracts["symbol"].str[3].astype(int)
    base_contracts.loc[:, "month_index"] = base_contracts["month_letter"].map(
        {letter: idx for idx, letter in enumerate(CORN_MONTH_ORDER)}
    )
    
    # Sort by year, then month
    base_contracts_sorted = base_contracts.sort_values(["year_digit", "month_index"])
    
    front_month = base_contracts_sorted.iloc[0]["symbol"]
    print(f"\nfront month contract is: {front_month}")
    
    return None

# %%
data_path:str = "../data/raw/mbo/glbx-mdp3-20260204.mbo.dbn" # 4th Feb 2026
show_info_for_single_day_data(data_path)
# Out:
#                                                      ts_event  rtype  \
# ts_recv
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-04 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# ...

# %%
data_path:str = "../data/raw/mbo/glbx-mdp3-20260205.mbo.dbn" # 5th Feb 2026
show_info_for_single_day_data(data_path)
# Out:
#                                                      ts_event  rtype  \
# ts_recv
# 2026-02-05 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-05 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-05 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-05 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-05 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
# 2026-02-05 00:00:00+00:00 2026-02-01 13:42:54.645765203+00:00    160
#
#                            publisher_id  instrument_id action side  price  \
# ts_recv
# 2026-02-05 00:00:00+00:00             1       42030576      R    N    NaN
# 2026-02-05 00:00:00+00:00             1       42030576      A    B  10.50
# 2026-02-05 00:00:00+00:00             1       42030576      A    B  10.25
# 2026-02-05 00:00:00+00:00             1       42030576      A    B   5.25
# 2026-02-05 00:00:00+00:00             1       42030576      A    B   5.00
# ...

# %%
data_path:str = "../data/raw/mbo/glbx-mdp3-20240204.mbo.dbn" # 4th Feb 2024
show_info_for_single_day_data(data_path)
# Out:
#                                                             ts_event  rtype  \
# ts_recv
# 2024-02-04 12:03:28.853292028+00:00 2024-02-04 12:03:28.737000+00:00    160
# 2024-02-04 12:03:28.868594683+00:00 2024-02-04 12:03:28.737000+00:00    160
# 2024-02-04 12:03:28.894811579+00:00 2024-02-04 12:03:28.787000+00:00    160
# 2024-02-04 12:03:28.895665799+00:00 2024-02-04 12:03:28.787000+00:00    160
# 2024-02-04 12:03:28.913755883+00:00 2024-02-04 12:03:28.837000+00:00    160
# 2024-02-04 12:03:28.922265450+00:00 2024-02-04 12:03:28.837000+00:00    160
#
#                                      publisher_id  instrument_id action side  \
# ts_recv
# 2024-02-04 12:03:28.853292028+00:00             1         229776      R    N
# 2024-02-04 12:03:28.868594683+00:00             1         487769      R    N
# 2024-02-04 12:03:28.894811579+00:00             1       42273528      R    N
# 2024-02-04 12:03:28.895665799+00:00             1         495552      R    N
# ...

# %%
data_path:str = "../data/raw/glbx-mdp3-202512030.mbo.dbn" # 5th Dec 2025
show_info_for_single_day_data(data_path)
# Out:
#  file NOT found: ../data/raw/glbx-mdp3-202512030.mbo.dbn
#  > This day does not exist in the dataset. Check the filename.

# %% [markdown]
# ### Investigating the processed front-month trades data (derived from MBO — trades only, no bid/ask book)

# %%
import pandas as pd

# this parquet was built from MBO data (trades only, no bid/ask).
# once MBP-10 data is downloaded and processed, use front_month_MBP10.parquet instead.
processed_trades_data = pd.read_parquet("../data/processed/MBO_20240205-20260205.parquet")
print(f"Shape: {processed_trades_data.shape}")
print(f"Columns: {processed_trades_data.columns.tolist()}")
print(f"Date range: {processed_trades_data['date'].min()} to {processed_trades_data['date'].max()}")
print(f"Contracts: {sorted(processed_trades_data['symbol'].unique())}")
processed_trades_data.head(5)
# Out:
# Shape: (5187471, 6)
# Columns: ['ts_event', 'price', 'size', 'side', 'symbol', 'date']
# Date range: 20240205 to 20260205
# Contracts: ['ZCH4', 'ZCH5', 'ZCH6', 'ZCK4', 'ZCK5', 'ZCN4', 'ZCN5', 'ZCU4', 'ZCU5', 'ZCZ4', 'ZCZ5']
#                              ts_event   price  size side symbol      date
# 0           2024-02-05 01:00:00+00:00  442.75   172    N   ZCH4  20240205
# 1 2024-02-05 01:00:00.002065937+00:00  442.75     1    B   ZCH4  20240205
# 2 2024-02-05 01:00:00.002833689+00:00  442.75     1    N   ZCH4  20240205
# 3 2024-02-05 01:00:00.003107105+00:00  442.50     6    A   ZCH4  20240205
# 4 2024-02-05 01:00:00.003107105+00:00  442.25     4    A   ZCH4  20240205

# %%
processed_trades_data.tail(5)
# Out:
#                                    ts_event   price  size side symbol  \
# 5187466 2026-02-05 19:19:53.426740793+00:00  435.25     1    A   ZCH6
# 5187467 2026-02-05 19:19:53.563423349+00:00  435.25    21    A   ZCH6
# 5187468 2026-02-05 19:19:55.070677539+00:00  435.25     1    N   ZCH6
# 5187469 2026-02-05 19:19:55.177567635+00:00  435.25     1    A   ZCH6
# 5187470 2026-02-05 19:19:59.325063653+00:00  435.25     6    A   ZCH6
#
#              date
# 5187466  20260205
# 5187467  20260205
# 5187468  20260205
# 5187469  20260205
# 5187470  20260205

# %%
# check to see if the futrures contract rolls over at the correct time
# i will do this by writing a function that takes in the input of the sumbol name (e.g. ZCH6) and then checks if the contract rolls over at the correct time. it will print a few rows that show this roll over happen (e.g 3 rows before and 3 rows after)

def check_contract_rollover(symbol: str) -> None: 

    contract_data = processed_trades_data[processed_trades_data['symbol'] == symbol]
    print( "\n .................. Start of Roll Over Period .................. \n ",contract_data[["date","symbol"]].head(5), "\n .................. End of Roll Over Period .................. \n ", contract_data[["date","symbol"]].tail(5))


#check_contract_rollover("ZCZ5")
check_contract_rollover("ZCZ5")
# Out:
#  .................. Start of Roll Over Period ..................
#                date symbol
# 4033700  20250915   ZCZ5
# 4033701  20250915   ZCZ5
# 4033702  20250915   ZCZ5
# 4033703  20250915   ZCZ5
# 4033704  20250915   ZCZ5
#  .................. End of Roll Over Period ..................
#                date symbol
# 4748696  20251212   ZCZ5
# 4748697  20251212   ZCZ5
# 4748698  20251212   ZCZ5
# 4748699  20251212   ZCZ5
# 4748700  20251212   ZCZ5

# %%
processed_trades_data['price'].describe().apply(lambda x: f'{x:.2f}') #make sure price seems legit, no outliers like $100 a bushel.
# Out:
# count    5187471.00
# mean         436.84
# std           27.51
# min          360.50
# 25%          420.75
# 50%          434.00
# 75%          454.00
# max          504.50
# Name: price, dtype: str

# %%
# Check for duplicates
print(processed_trades_data.duplicated(subset=["date","symbol","price","size"]).sum()) #->4723206
print(processed_trades_data.duplicated().sum())  # -> 19715

# this output is a little sus, but should be fine since it is only 0.004% of the data and it is common for the same trade to be reported multiple times or even happen at the same time.
# Out:
# 4723206
# 19715

# %%
processed_trades_data.duplicated().sum()
# Out:
# np.int64(19715)

# %%
# bid-ask spread check (crossed books)
# a "crossed book" means bid > ask, which shouldn't happen in a healthy market.
# requires MBP-10 processed data:
#   python scripts/process_all_data.py --data-dir data/raw/mbp10 --output data/processed/front_month_MBP10.parquet

book_path = "../data/processed/front_month_MBP10.parquet"
book_df = pd.read_parquet(book_path)

# only check rows that have both bid and ask prices
valid = book_df.dropna(subset=['bid_px_00', 'ask_px_00'])

crossed = valid[valid['bid_px_00'] > valid['ask_px_00']]
print(f"crossed books: {len(crossed)} out of {len(valid)} rows ({len(crossed)/len(valid)*100:.4f}%)")

if not crossed.empty:
    display(crossed.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 8
#       5 raw_df = raw_store.to_df()
#       7 # only check rows that have both bid and ask prices
# ----> 8 has_both = raw_df[['bid_px_00', 'ask_px_00']].dropna().index
#       9 valid = raw_df.loc[has_both]
#      11 crossed = valid[valid['bid_px_00'] > valid['ask_px_00']]
#
# File c:\Users\dannb\_projects\code\active\corn_futures_research\venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# ...
