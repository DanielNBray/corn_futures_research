# %% [markdown]
# ### Investigating the **RAW MBP-10 Data**, day-by-day
# - sample rows and column types
# - action breakdown table (trades, adds, cancels, etc.)
# - size of daily data (in rows and cols)
# - symbol counts
# - front month contract identification
# - display bid/ask/mid chart for front month contract for the daily data

# %%
import databento as db
import pandas as pd
from pathlib import Path
from IPython.display import display


pd.set_option('display.max_rows', None)  # set to NONE so that we get the entire fucking output
pd.set_option('display.max_columns', None)  

# consts
CORN_MONTH_ORDER = {3:"H", 5:"K", 7:"N", 9:"U", 12:"Z"}  # March, May, July, Sep, Dec
ACTION_CODES = ["T", "A", "R", "C", "F", "N", "M"]
ACTION_LABELS = ["trades", "adds", "clears", "cancels", "fills", "none", "modify"]

# quick style function for output
def title_and_spaces(title: str = "") -> None:
    print("\n", 40 * "-", ) #    ---------------------------------------- 
    print("\t",title,"\t")  #       Title
    print(41 * "-","\n")    #     ---------------------------------------- 
    return None

def show_info_for_single_day_data(data_path : str = "../data/raw/MPB10_20250216-20260216/glbx-mdp3-20250216.mbp-10.dbn" ) -> pd.DataFrame:
    """
    Display a quick summary of a single day's corn futures market data.
    - sample rows and column types
    - action breakdown table (trades, adds, cancels, etc.)
    - symbol counts
    - front month contract identification
    - display bid/ask/mid chart for front month contract for the daily data
    """

    file_path = Path(data_path) # input validation
    if not file_path.exists():
        return f"This file is not found: {data_path}. Check if the day exists in the dataset and that the name is spelt correctly"


    corn_dbn_file = db.DBNStore.from_file(data_path)
    corn_daily_df = corn_dbn_file.to_df()
    
    title_and_spaces("shape of db")
    print(corn_daily_df.shape)

    title_and_spaces("Columns")
    print(corn_daily_df.columns)


    title_and_spaces("Types of Each Column")
    print(corn_daily_df.dtypes)
    
    
   
    title_and_spaces("Types of actions")
    action_counts = corn_daily_df['action'].value_counts()
    print(action_counts)
    
    title_and_spaces("Types of Assets")
    symbol_counts = corn_daily_df['symbol'].value_counts()
    print(symbol_counts)
    
    title_and_spaces("Flags")
    flags = corn_daily_df['flags'].value_counts()
    print(flags)

    # symbol_counts_df = pd.DataFrame({
    #     "symbol": symbol_counts.index,
    #     "count": symbol_counts.values,
    # })
    # display(symbol_counts_df)
    #symbol_counts_df.plot.bar(title="DataFrame Plot")    # this is stupid, i dont know why i spent the time figuring this out, but ill leave it here cause syntax will prob be used again

    
    def get_front_month(date:str = "20250216") -> str:
        
        contract = "ZC"

        if len(date) != 8:
            return "date fucked up"
        
        year = date[:4]
        month = int(date[4:6])
        day = int(date[6:8])

        if day >= 15: # so that if we get a March 16th, we dont look for a ZCH- contract
            month += 1
            year = str(int(year)+1)
        
        # 3:"H", 5:"K", 7:"N", 9:"U", 12:"Z"

        if month <= 3:
            contract += CORN_MONTH_ORDER[3]
        elif month <= 5:
            contract += CORN_MONTH_ORDER[5]
        elif month <= 7:
            contract += CORN_MONTH_ORDER[7]
        elif month <= 9:
            contract += CORN_MONTH_ORDER[9]
        else:
            contract += CORN_MONTH_ORDER[12]
    
        contract += year[3]

        return contract
    
    def get_date_from_filepath(data_path : str = "../data/raw/MPB10_20250216-20260216/glbx-mdp3-20250216.mbp-10.dbn" ) -> str:
        date_index = data_path.find("glbx-mdp3-") + len("glbx-mdp3-")
        return data_path[date_index: date_index + 8] # 8 because that is length of date string


    date = get_date_from_filepath(data_path)
    contract = get_front_month(date)
    front_month = corn_daily_df[corn_daily_df['symbol'] == contract].copy()
    front_month['mid'] = (front_month['bid_px_00'] + front_month['ask_px_00'])/2
    front_month_timeseries = front_month[['bid_px_00','ask_px_00','mid']]
    print(type(front_month))
    front_month_timeseries.plot.line(title="Bid Ask Mid for Front Futures Contract", figsize = (20,9))


    title_and_spaces("front Contract")
    print(contract)


    #return corn_daily_df.head(10)
    return front_month.head(10)

# %%
show_info_for_single_day_data("../data/raw/MPB10_20250216-20260216/glbx-mdp3-20250516.mbp-10.dbn")
# Out:
#  ----------------------------------------
# 	 shape of db
# -----------------------------------------
#
# (1200030, 73)
#
#  ----------------------------------------
# 	 Columns
# -----------------------------------------
#
# Index(['ts_event', 'rtype', 'publisher_id', 'instrument_id', 'action', 'side',
#        'depth', 'price', 'size', 'flags', 'ts_in_delta', 'sequence',
#        'bid_px_00', 'ask_px_00', 'bid_sz_00', 'ask_sz_00', 'bid_ct_00',
#        'ask_ct_00', 'bid_px_01', 'ask_px_01', 'bid_sz_01', 'ask_sz_01',
#        'bid_ct_01', 'ask_ct_01', 'bid_px_02', 'ask_px_02', 'bid_sz_02',
#        'ask_sz_02', 'bid_ct_02', 'ask_ct_02', 'bid_px_03', 'ask_px_03',
#        'bid_sz_03', 'ask_sz_03', 'bid_ct_03', 'ask_ct_03', 'bid_px_04',
#        'ask_px_04', 'bid_sz_04', 'ask_sz_04', 'bid_ct_04', 'ask_ct_04',
#        'bid_px_05', 'ask_px_05', 'bid_sz_05', 'ask_sz_05', 'bid_ct_05',
#        'ask_ct_05', 'bid_px_06', 'ask_px_06', 'bid_sz_06', 'ask_sz_06',
# ...

# %%
show_info_for_single_day_data("../data/raw/MPB10_20250216-20260216/glbx-mdp3-20260118.mbp-10.dbn")
# Out:
#  ----------------------------------------
# 	 shape of db
# -----------------------------------------
#
# (401, 73)
#
#  ----------------------------------------
# 	 Types of actions
# -----------------------------------------
#
# action
# A    208
# C    174
# M     19
# Name: count, dtype: int64
#
#  ----------------------------------------
# 	 Types of Assets
# -----------------------------------------
#
# symbol
# ZCH6              71
# ZCK7-ZCN7         54
# ZCH7-ZCK7         40
# ZCH6-ZCK6         23
# ZCK6-ZCN6         22
# ZCZ6-ZCH7         21
# ZCN6-ZCU6         19
# ZCU6-ZCZ6         19
# ZCH6-ZCU6         12
# ZCZ7-ZCH8          9
# ZCZ6-ZCZ7          7
# ZC:BF H6-K6-N6     6
# ZCK6-ZCU6          6
# ZCU7-ZCZ7          6
# ZCZ6               6
# ZCU6-ZCH7          4
# ZCH6-ZCN6          3
# ZCN6               3
# ZC:BF H7-K7-N7     2
# ZCH6-ZCH7          2
# ZCN7               2
# ZCN7-ZCZ7          2
# ZCU6-ZCN7          2
# ZC:BF K6-N6-U6     1
# ZC:BF N6-U6-Z6     1
# ...

# %% [markdown]
# # Investigating Broader features: **Activity breakdown** by day - the number of actions taken (add, cancel, modify, trade, etc)
# ### Only investigation traditional futures, so symbols like 'ZCK7-ZCN7' or 'ZC:CF N7U7Z7H8' are excluded. Put simply, only care about the 4 character length symbols like ZCH6 and ZCN4.
#
# - outputing the number or rows for the daily data
# - and displaying a timeseries graph, with each line representing a day of the week to inidicate repeating trends (Sundays typically show less activity)

# %%
# testing if converting to dataframe than using shape would work, it does. but maybe not optimal. I will keep this here to debug specific days.

data_path="../data/raw/MPB10_20250216-20260216/glbx-mdp3-20260118.mbp-10.dbn"
corn_dbn_file = db.DBNStore.from_file(data_path)
corn_daily_df = corn_dbn_file.to_df()
(x,y) = corn_daily_df.shape
x
# Out:
# 401

# %%
from pathlib import Path
from datetime import date
from collections import defaultdict
import databento as db
import plotly.graph_objects as go

day_data = defaultdict(list)  # weekday -> [(date, count)]

for y in range(5, 7):
    for m in range(1, 13):
        for d in range(1, 32):
            month, day = f"{m:02d}", f"{d:02d}"

            data_path = Path(f"../data/raw/MPB10_20250216-20260216/glbx-mdp3-202{y}{month}{day}.mbp-10.dbn")
            if not data_path.exists():
                continue

            store = db.DBNStore.from_file(str(data_path))

            corn_daily_df = store.to_df()[["symbol"]]
            rows = int(corn_daily_df["symbol"].str.len().eq(4).sum())

            dt = date(2020 + y, m, d)
            weekday = dt.strftime("%A")

            print(f"{weekday}:\t \t {rows}  \t \t {i}/313")  # the 313 represents number of files.
            i += 1
            if weekday != "Saturday":
                day_data[weekday].append((dt, rows))

# >> plot 
WEEKDAY_ORDER = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Sunday"]

fig = go.Figure()

for weekday in WEEKDAY_ORDER:
    if weekday not in day_data:
        continue
    entries = sorted(day_data[weekday])
    dates  = [e[0] for e in entries]
    counts = [e[1] for e in entries]
    fig.add_trace(go.Scatter(x=dates, y=counts, mode="lines", name=weekday))

fig.update_layout(
    title="MBP-10 Row Count by Weekday for traditional corn futures contracts (2025–2026)",
    legend=dict(orientation="h", yanchor="bottom", y=1.05, xanchor="center", x=0.5)
)
fig.update_xaxes(title_text="Date")
fig.update_yaxes(title_text="Row count")
fig.show()
# Out:
# Sunday:	 	 74  	 	 1/313
# Monday:	 	 380  	 	 2/313
# Tuesday:	 	 803016  	 	 3/313
# Wednesday:	 	 698507  	 	 4/313
# Thursday:	 	 704813  	 	 5/313
# Friday:	 	 666875  	 	 6/313
# Sunday:	 	 156  	 	 7/313
# Monday:	 	 918172  	 	 8/313
# Tuesday:	 	 1179981  	 	 9/313
# Wednesday:	 	 767910  	 	 10/313
# Thursday:	 	 866785  	 	 11/313
# Friday:	 	 1068506  	 	 12/313
# Sunday:	 	 117  	 	 13/313
# Monday:	 	 1195539  	 	 14/313
# Tuesday:	 	 1826624  	 	 15/313
# Wednesday:	 	 1318437  	 	 16/313
# Thursday:	 	 1358285  	 	 17/313
# Friday:	 	 891209  	 	 18/313
# Sunday:	 	 390  	 	 19/313
# Monday:	 	 873741  	 	 20/313
# Tuesday:	 	 951013  	 	 21/313
# Wednesday:	 	 1030132  	 	 22/313
# Thursday:	 	 835984  	 	 23/313
# Friday:	 	 767463  	 	 24/313
# Sunday:	 	 504  	 	 25/313
# Monday:	 	 764620  	 	 26/313
# Tuesday:	 	 691664  	 	 27/313
# Wednesday:	 	 730839  	 	 28/313
# Thursday:	 	 768156  	 	 29/313
# Friday:	 	 1016113  	 	 30/313
# Sunday:	 	 449  	 	 31/313
# ...

# %% [markdown]
# # Results (as a chart)
#
# ![Image of sample data visualised in dataframe format](../outputs/charts/MBP-10_row_count_by_weekday_for_all_traditional_corn_futures_contracts.png)
