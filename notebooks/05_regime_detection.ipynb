# %% [markdown]
# ## 05 — Regime Detection
# HMM on log(RV), OU process fit, OU z-score, OFI confirmation filter; build and save `signal_table.parquet`. Uses `src.models.regime` and micro_features / daily_vol_table.
